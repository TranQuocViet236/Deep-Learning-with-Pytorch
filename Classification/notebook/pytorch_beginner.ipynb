# %%
# !pip show torch

# %%
# !pip show numpy

# %%
import torch

# %%
x = torch.empty(5, 3)
x

# %%
x = torch.rand(5, 3)
x

# %%
x = torch.zeros(5, 3, dtype= torch.long)
x

# %%
x = torch.ones((5, 3))
x

# %%
y = torch.randn_like(x, dtype= torch.double)
y

# %%
y.shape
y.size()

# %%
x

# %%
y = torch.rand((5, 3))
y

# %%
z = x + y
z

# %%
z = torch.add(x, y)
z

# %%
y.add_(x)
y

# %%
xx = x.view(15)
xx.shape

# %%
new_x = torch.randn(1)

# %%
new_x.item()

# %%
x = torch.rand(3, 3)
x

# %%
x[0, 0]

# %%
x[0, 0].item()

# %%
y = x.numpy()

# %%
y

# %%
import numpy as np
a = np.ones(3)

# %%
a

# %%
b = torch.from_numpy(a)
b

# %%
 device = torch.cuda.is_available()
 device

# %%
if torch.cuda.is_available():
  device = torch.device("cuda")
  y = torch.ones_like(x, device=device)
  x = x.to(device)
  z = x + y
  print(z)

# %%
#cpu(): chuyển về tính toán trên cpu

# %%
x = torch.tensor(2.0, requires_grad=True)
x

# %%
y = torch.exp(x)
y

# %%
y.backward()

# %%
x.grad

# %% [markdown]
# torch.Tensor:
#   - required_grad: có lưu thông tin gradient không?
#   - grad_fn: lưu thông tin hàm số đã sử dụng
#   - backward(): hàm đạo hàm
#   - grad: lưu các thông tin đạo hàm
